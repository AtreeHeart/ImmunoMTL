# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_radar_by_tool(metric, group_name, values, input_dir, save_path):
    cluster_labels = [f"Cluster {i+1}" for i in range(len(values))]
    model_scores = {}

    # Define custom color set
    color_set = ["#4E526E", "#E07A5F", "#F0C3AF", "#F6D5A0", "#92BEAA", "#718B8E"]

    # Load and aggregate model scores
    for val in values:
        file_path = os.path.join(input_dir, f"BenchmarkSet_bootstrap_{group_name}_{val}_{metric}.csv")
        if not os.path.exists(file_path):
            print(f"[SKIP] {file_path} not found.")
            continue

        df = pd.read_csv(file_path)
        df = df.drop(columns=["IEPAPI", "EL_score"], errors='ignore')
        for model in df.columns:
            if model not in model_scores:
                model_scores[model] = []
            model_scores[model].append(df[model].mean())

    # Radar plot setup
    angles = np.linspace(0, 2 * np.pi, len(values), endpoint=False).tolist()
    angles += angles[:1]

    fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

    # Plot each model
    for i, (model, scores) in enumerate(model_scores.items()):
        if len(scores) != len(values):
            continue
        values_loop = scores + [scores[0]]
        color = color_set[i % len(color_set)]
        ax.plot(angles, values_loop, label=model, linewidth=2, color=color)

        # Add dots at each axis for clarity
        for angle, val in zip(angles[:-1], scores):
            ax.plot(angle, val, 'o', color=color, markersize=4)

    # Style adjustments
    ax.grid(color="#E8E8E8", linewidth=1)
    ax.spines['polar'].set_color("#E8E8E8")
    ax.spines['polar'].set_linewidth(2)
    ax.set_theta_offset(np.pi / 2)
    ax.set_theta_direction(-1)
    ax.set_thetagrids([])

    # Manually add radial axis labels (one per cluster)
    label_radius = ax.get_ylim()[1] + 0.1  # slightly outside outermost radius
    for angle, label in zip(angles[:-1], cluster_labels):
        ax.text(
            angle,
            label_radius,
            label,
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=14,
            fontweight='normal'
            #rotation=np.degrees(angle),
            #rotation_mode='anchor'
        )
    ax.set_title(f"{metric} across MMS clusters", fontsize=16, pad=60, fontweight='normal')
    ax.set_ylim(0.3, 0.7)
    ax.set_yticks(np.linspace(0.3, 0.75, 4))
    ax.set_rlabel_position(300)
    ax.yaxis.set_tick_params(labelsize=14, pad=20)
    ax.yaxis.grid(True, color="#E8E8E8", linewidth=1)  # horizontal rings
    ax.xaxis.grid(True, color="#E8E8E8", linewidth=1)  # vertical spokes
    
    ax.legend(loc='upper right', bbox_to_anchor=(1.2, 0.3), fontsize=14)

    plt.tight_layout()
    #plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"[SAVED] {save_path}")
    plt.show()

# %%
input_dir = "../analysis/groupwise_bootstrap"
output_dir = "../analysis"
os.makedirs(output_dir, exist_ok=True)

lengths = [0.0, 1.0, 2.0, 3.0]
for metric in ["AUROC", "AP"]:
    out_path = os.path.join(output_dir, f"Radar_Length_{metric}.png")
    plot_radar_by_tool(metric, "MMS_Cluster", lengths, input_dir, out_path)
# Out:
# [SAVED] ../analysis/Radar_Length_AUROC.png
# [SAVED] ../analysis/Radar_Length_AP.png
